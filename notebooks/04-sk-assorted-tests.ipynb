# %%
pip install --upgrade --force-reinstall numpy scipy
# Out:
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/75/c9/9bec03675192077467a9c7c2bdd1f2e922bd01d3a69b15c3a0fdcd8548f6/numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 1.7 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/af/2c/40108915fd340c830aee332bb85a9160f99e90893e58008b659b9f3dddc0/scipy-1.16.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 60.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 37.0 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: scipy
# ...

# %%
pip install -e ..
# Out:
# Obtaining file:///home/sagar/winogender_contextuality
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for winogender_contextuality (pyproject.toml) ... done
#   Created wheel for winogender_contextuality: filename=winogender_contextuality-0.0.1-py3-none-any.whl size=3560 sha256=bbf675f1ff1d7b7cd027bac5bb1eedb1e30e6a1f581cfd88de8f31cec5f7e462
#   Stored in directory: /tmp/pip-ephem-wheel-cache-d9wg_9ku/wheels/49/60/47/f23891bb1a09f2022418df9bc5d11c1d70a33f8f18763de816
# Successfully built winogender_contextuality
# ...
#   Attempting uninstall: winogender_contextuality
#     Found existing installation: winogender_contextuality 0.0.1
#     Uninstalling winogender_contextuality-0.0.1:
#       Successfully uninstalled winogender_contextuality-0.0.1
# ...

# %% [raw]
# import winogender_contextuality

# %%
from winogender_contextuality.modeling.contextuality import *
# Out:
# 2025-07-21 19:04:11.653 | INFO     | winogender_contextuality.config:<module>:13 - PROJ_ROOT path is: /home/sagar/winogender_contextuality
# 2025-07-21 19:04:11.653 | INFO     | winogender_contextuality.config:<module>:17 - DATA_ROOT path is: /data_users1/sagar/winogender_contextuality
# 2025-07-21 19:04:17.861019: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753139057.882682 1140179 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753139057.889342 1140179 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
test = MeasurementScenario(
    observations = ['a', 'b'],
    measurements = ['reg', 'prime'],
    outcomes = [0,1]
)
# Out:
# ---------------------------------------------------------------------------
# MissingDimensionsError                    Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 test = MeasurementScenario(
#       2     observations = ['a', 'b'],
#       3     measurements = ['reg', 'prime'],
#       4     outcomes = [0,1]
#       5 )
#
# File ~/winogender_contextuality/winogender_contextuality/modeling/contextuality.py:64, in MeasurementScenario.__init__(self, observations, measurements, outcomes)
#      61 self.outcome_pairs = list(product(self.outcomes, repeat=len(self.measurements)))
#      63 # Empty measurement scenario matrix
# ---> 64 self.scenario = xr.DataArray(np.zeros((len(self.context_pairs), len(self.outcome_pairs))),
#      65                              dims=['context_pair', 'outcome_pair'],
#      66                              coords=[self.context_pairs, self.outcome_pairs])
#
# ...
